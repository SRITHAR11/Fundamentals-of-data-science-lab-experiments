# %%
import pandas as pd 
import matplotlib.pyplot as plt
data = {'Year': list(range(2010, 2021)), 'Job Postings': [155, 305, 455, 605, 805, 1205, 1605, 2105, 2705, 3405, 4205]} 
df = pd.DataFrame(data)
plt.plot(df['Year'], df['Job Postings'], marker='o') 
plt.title('Trend of Data Science Job Postings')
plt.xlabel('Year')
plt.ylabel('Number of Job Postings') 
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = {'Role': ['Data Analyst', 'Data Scientist', 'Data Engineer',
             'Machine Learning Engineer', 'Business Analyst'],
    'Count': [125, 185, 105, 85, 75]}
df = pd.DataFrame(data)
plt.bar(df['Role'], df['Count'])
plt.title('Distribution of Data Science Roles')
plt.xlabel('Job Roles')
plt.ylabel('Number of Employees')
plt.xticks(rotation=20)
plt.show()

# %%
import pandas as pd
structured_data = {
    'ID': [1, 2, 3],
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [23, 27, 25]
}
unstructured_data = {
    'Text': [
        'Data Science is interesting.',
        'Python is easy to learn.',
        'Big Data is the future.'
    ]
}
semi_structured_data = {
    'Student': [
        {'ID': 1, 'Name': 'sri', 'Marks': 90},
        {'ID': 2, 'Name': 'bala', 'Marks': 78},
        {'ID': 3, 'Name': 'sai', 'Marks': 98}
    ]
}
df1 = pd.DataFrame(structured_data)
df2 = pd.DataFrame(unstructured_data)
df3 = pd.DataFrame(semi_structured_data)
print("Structured Data")
print(df1)
print("\nUn-Structured Data")
print(df2)
print("\nSemi-Structured Data")
print(df3)
# Out:
# Structured Data
#    ID     Name  Age
# 0   1    Alice   23
# 1   2      Bob   27
# 2   3  Charlie   25
#
# Un-Structured Data
#                            Text
# 0  Data Science is interesting.
# 1      Python is easy to learn.
# 2       Big Data is the future.
#
# Semi-Structured Data
#                                   Student
# 0   {'ID': 1, 'Name': 'sri', 'Marks': 90}
# 1  {'ID': 2, 'Name': 'bala', 'Marks': 78}
# 2   {'ID': 3, 'Name': 'sai', 'Marks': 98}

# %%
from cryptography.fernet import Fernet
key = Fernet.generate_key()
cipher = Fernet(key)
data = "My Password is 54321"
encrypted_data = cipher.encrypt(data.encode())
decrypted_data = cipher.decrypt(encrypted_data).decode()
print("Original Data:", data)
print("Encrypted Data:", encrypted_data)
print("Decrypted Data:", decrypted_data)
# Out:
# Original Data: My Password is 54321
# Encrypted Data: b'gAAAAABqch7Vcvq-2-wchBGwUnQSAGq5wm0jY0nHp3FqcOP1rC3Fdgf5aglejNbhnyOxJr6bMyuqYZ8-lHieKQKZq5as0OMXOj4JJ0wdEiwWBJqly6I9zGc='
# Decrypted Data: My Password is 54321
